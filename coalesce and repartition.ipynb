# %%
dbutils.fs.ls('/Volumes/workspace/bronze/circuit')

# %%
df=spark.read.option('header','true').csv('/Volumes/workspace/bronze/circuit/circuits.csv')
df.show()

# %%
df1=spark.read.format('json').load('/Volumes/workspace/bronze/circuit/sparkify_log_small.json')

# %%
print(len(df1.columns))
print(df1.count())

# %%
df1.count()
df1.show()
df1.display()

# %%
df1.display()
